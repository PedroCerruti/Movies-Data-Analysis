# %% [markdown]
# # Data Analysis & Data Presentation - Movies Dataset

# %% [markdown]
# __Features/Columns__:
# * **id:** The ID of the movie (clear/unique identifier).
# * **title:** The Official Title of the movie.
# * **tagline:** The tagline of the movie.
# * **release_date:** Theatrical Release Date of the movie.
# * **genres:** Genres associated with the movie.
# * **belongs_to_collection:** Gives information on the movie series/franchise the particular film belongs to.
# * **original_language:** The language in which the movie was originally shot in.
# * **budget_musd:** The budget of the movie in million dollars.
# * **revenue_musd:** The total revenue of the movie in million dollars.
# * **production_companies:** Production companies involved with the making of the movie.
# * **production_countries:** Countries where the movie was shot/produced in.
# * **vote_count:** The number of votes by users, as counted by TMDB.
# * **vote_average:** The average rating of the movie.
# * **popularity:** The Popularity Score assigned by TMDB.
# * **runtime:** The runtime of the movie in minutes.
# * **overview:** A brief blurb of the movie.
# * **spoken_languages:** Spoken languages in the film.
# * **poster_path:** The URL of the poster image.
# * **cast:** (Main) Actors appearing in the movie.
# * **cast_size:** number of Actors appearing in the movie.
# * **director:** Director of the movie.
# * **crew_size:** Size of the film crew (incl. director, excl. actors).

# %% [markdown]
# ## Data Import and first Inspection

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
pd.options.display.max_columns = 30
pd.options.display.float_format = '{:.2f}'.format

# %%
df = pd.read_csv("movies_complete.csv", parse_dates=["release_date"])

# %%
df.shape
# Out:
# (44753, 22)

# %%
df.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3  Friends are the people who let you be yourself...   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                      genres           belongs_to_collection original_language  \
# 0   Animation|Comedy|Family            Toy Story Collection                en
# 1  Adventure|Fantasy|Family                             NaN                en
# 2            Romance|Comedy       Grumpy Old Men Collection                en
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44753 entries, 0 to 44752
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44753 non-null  int64
#  1   title                  44753 non-null  object
#  2   tagline                20285 non-null  object
#  3   release_date           44712 non-null  datetime64[ns]
#  4   genres                 42591 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44743 non-null  object
#  7   budget_musd            8854 non-null   float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33356 non-null  object
#  10  production_countries   38838 non-null  object
#  11  vote_count             44753 non-null  float64
#  12  vote_average           42097 non-null  float64
#  13  popularity             44753 non-null  float64
# ...

# %%
df.genres[1]
# Out:
# 'Adventure|Fantasy|Family'

# %%
df.cast[1]
# Out:
# 'Robin Williams|Jonathan Hyde|Kirsten Dunst|Bradley Pierce|Bonnie Hunt|Bebe Neuwirth|David Alan Grier|Patricia Clarkson|Adam Hann-Byrd|Laura Bell Bundy|James Handy|Gillian Barber|Brandon Obray|Cyrus Thiedeke|Gary Joseph Thorup|Leonard Zola|Lloyd Berry|Malcolm Stewart|Annabel Kershaw|Darryl Henriques|Robyn Driscoll|Peter Bryant|Sarah Gilson|Florica Vlad|June Lion|Brenda Lockmuller'

# %%
df.describe()
# Out:
#              id  budget_musd  revenue_musd  vote_count  vote_average  \
# count  44753.00      8854.00       7385.00    44753.00      42097.00
# mean  107421.24        21.67         68.97      111.50          6.00
# std   111951.77        34.36        146.61      495.00          1.28
# min        2.00         0.00          0.00        0.00          0.00
# 25%    26119.00         2.00          2.41        3.00          5.30
# 50%    59230.00         8.20         16.87       10.00          6.10
# 75%   155169.00        25.00         67.64       35.00          6.80
# max   469172.00       380.00       2787.97    14075.00         10.00
#
#        popularity  runtime  cast_size  crew_size
# count    44753.00 43223.00   44753.00   44753.00
# mean         2.95    97.54      12.46      10.30
# std          6.04    34.71      12.12      15.89
# min          0.00     1.00       0.00       0.00
# 25%          0.40    86.00       6.00       2.00
# ...

# %%
df.hist(figsize= (20, 12), bins = 100)
plt.show()

# %%
df.budget_musd.value_counts(dropna= False).head(20)
# Out:
# NaN      35899
# 5.00       286
# 10.00      258
# 20.00      243
# 2.00       241
# 15.00      226
# 3.00       220
# 25.00      206
# 1.00       195
# 30.00      189
# 4.00       180
# 6.00       173
# 12.00      171
# 40.00      166
# 8.00       155
# 35.00      141
# 0.50       141
# 7.00       137
# 50.00      124
# 1.50       119
# Name: budget_musd, dtype: int64

# %%
df.revenue_musd.value_counts(dropna= False).head(20)
# Out:
# NaN      37368
# 12.00       20
# 10.00       19
# 11.00       19
# 2.00        18
# 6.00        17
# 5.00        14
# 0.50        13
# 8.00        13
# 0.00        12
# 14.00       12
# 7.00        11
# 3.00        10
# 1.00        10
# 20.00       10
# 0.00         9
# 1.50         9
# 4.00         9
# 30.00        8
# 4.10         8
# Name: revenue_musd, dtype: int64

# %%
df.vote_average.value_counts(dropna= False)
# Out:
# NaN     2656
# 6.00    2428
# 5.00    1971
# 7.00    1860
# 6.50    1705
#         ...
# 9.40       3
# 9.60       1
# 9.80       1
# 0.70       1
# 1.10       1
# Name: vote_average, Length: 93, dtype: int64

# %%
df.vote_count.value_counts()
# Out:
# 1.00       3201
# 2.00       3059
# 3.00       2730
# 0.00       2656
# 4.00       2442
#            ...
# 2755.00       1
# 1187.00       1
# 4200.00       1
# 3322.00       1
# 2712.00       1
# Name: vote_count, Length: 1820, dtype: int64

# %%
df.describe(include='object')
# Out:
#              title                 tagline genres belongs_to_collection  \
# count        44753                   20285  42591                  4463
# unique       41666                   20172   4044                  1691
# top     Cinderella  Based on a true story.  Drama       The Bowery Boys
# freq            11                       7   4936                    29
#
#        original_language       production_companies      production_countries  \
# count              44743                      33356                     38838
# unique                89                      22537                      2377
# top                   en  Metro-Goldwyn-Mayer (MGM)  United States of America
# freq               31811                        741                     17723
#
#                                     overview spoken_languages  \
# count                                  43795            41097
# unique                                 43770             1828
# ...

# %%
df[df.title=='Cinderella']
# Out:
#            id       title                             tagline release_date  \
# 985     11224  Cinderella  The greatest love story ever told.   1950-03-04
# 12995   42884  Cinderella                                 NaN   1997-11-02
# 23270   92349  Cinderella                                 NaN   1914-12-28
# 23281  105875  Cinderella          The version children love!   2002-08-06
# 28091  261985  Cinderella                                 NaN   2011-10-30
# 28359  150689  Cinderella     Midnight is just the beginning.   2015-03-12
# 33829   42651  Cinderella                                 NaN   1947-11-28
# 35140   44459  Cinderella                                 NaN   1957-03-31
# 35142  289673  Cinderella                                 NaN   2000-01-01
# 40480  114108  Cinderella                                 NaN   1899-10-01
# 44694   98604  Cinderella                                 NaN   2012-02-14
#
# ...

# %% [markdown]
# ## The best and the worst movies:
# - Highest Revenue
# - Highest Budget
# - Highest Profit (=Revenue - Budget)
# - Lowest Profit (=Revenue - Budget)
# - Highest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Lowest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Highest number of Votes
# - Highest Rating (only movies with 10 or more Ratings)
# - Lowest Rating (only movies with 10 or more Ratings)
# - Highest Popularity

# %%
from IPython.display import HTML
pd.options.display.max_colwidth = 200

# %%
df_best = df[["poster_path", "title", "budget_musd", "revenue_musd",
              "vote_count", "vote_average", "popularity"]].copy()
df_best
# Out:
#                                                                                              poster_path  \
# 0      <img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>
# 1      <img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'>
# 2      <img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'>
# 3      <img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'>
# 4      <img src='http://image.tmdb.org/t/p/w185//lf9RTErt8BSLQy98aSFblElvsCQ.jpg' style='height:100px;'>
# ...                                                                                                  ...
# 44748  <img src='http://image.tmdb.org/t/p/w185//pfC8gZ1BQANxxdadIMpdywbPG9X.jpg' style='height:100px;'>
# 44749  <img src='http://image.tmdb.org/t/p/w185//xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg' style='height:100px;'>
# ...

# %%
df_best["profit_musd"] = df.revenue_musd.sub(df.budget_musd)
df_best["return"] = df.revenue_musd.div(df.budget_musd)

# %%
df_best
# Out:
#                                                                                              poster_path  \
# 0      <img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>
# 1      <img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'>
# 2      <img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'>
# 3      <img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'>
# 4      <img src='http://image.tmdb.org/t/p/w185//lf9RTErt8BSLQy98aSFblElvsCQ.jpg' style='height:100px;'>
# ...                                                                                                  ...
# 44748  <img src='http://image.tmdb.org/t/p/w185//pfC8gZ1BQANxxdadIMpdywbPG9X.jpg' style='height:100px;'>
# 44749  <img src='http://image.tmdb.org/t/p/w185//xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg' style='height:100px;'>
# ...

# %%
df_best.columns = ["", "Title", "Budget", "Revenue", "Votes", 
                   "Average Rating", "Popularity", "Profit", "ROI"]

# %%
df_best.set_index("Title", inplace = True)

# %%
df_best
# Out:
#                                                                                                                                 \
# Title
# Toy Story                    <img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>
# Jumanji                      <img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'>
# Grumpier Old Men             <img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'>
# Waiting to Exhale            <img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'>
# Father of the Bride Part II  <img src='http://image.tmdb.org/t/p/w185//lf9RTErt8BSLQy98aSFblElvsCQ.jpg' style='height:100px;'>
# ...                                                                                                                        ...
# ...

# %%
high_rat = df_best.sort_values(by='Average Rating', ascending=False).head(5)
high_rat
# Out:
#                                                                                                                                                      \
# Title
# The Walking Stick                                 <img src='http://image.tmdb.org/t/p/w185//sT09bLZumszBg1QTBB6q8Ku1Adf.jpg' style='height:100px;'>
# The Kreutzer Sonata                               <img src='http://image.tmdb.org/t/p/w185//3ugwUvyEfOuV2CrL3ecd8NZyEcC.jpg' style='height:100px;'>
# Survive and Advance                                <img src='http://image.tmdb.org/t/p/w185//7w9YZnvsNAfdVbzvLfdn5w0yY4.jpg' style='height:100px;'>
# Frankie Boyle: Hurt Like You've Never Been Loved  <img src='http://image.tmdb.org/t/p/w185//v2ryvvl0ArGhQSpwvLcrzMlFZw1.jpg' style='height:100px;'>
# Lad: A Yorkshire Story                            <img src='http://image.tmdb.org/t/p/w185//wJuFDQB7UDKjaoxMEFsfm1nV5C3.jpg' style='height:100px;'>
#
#                                                   Budget  Revenue  Votes  \
# Title
# ...

# %%
high_roi = df_best.sort_values(by='ROI', ascending=False).head(5)
high_roi
# Out:
#                                                                                                                             \
# Title
# Less Than Zero           <img src='http://image.tmdb.org/t/p/w185//1GY0ZhAxOR2RgxGnOkeKoKb2mFM.jpg' style='height:100px;'>
# Modern Times             <img src='http://image.tmdb.org/t/p/w185//7uoiKOEjxBBW0AgDGQWrlfGQ90w.jpg' style='height:100px;'>
# Welcome to Dongmakgol     <img src='http://image.tmdb.org/t/p/w185//5iGVw8AdnUJ3xNaZ5iipfsv2e5.jpg' style='height:100px;'>
# Aquí Entre Nos           <img src='http://image.tmdb.org/t/p/w185//oflxxk94TjmjMdotXnajh64iMad.jpg' style='height:100px;'>
# The Karate Kid, Part II  <img src='http://image.tmdb.org/t/p/w185//mSne9mfUcL8QCGxF891LWa7lZNI.jpg' style='height:100px;'>
#
#                          Budget  Revenue  Votes  Average Rating  Popularity  \
# Title
# Less Than Zero             0.00    12.40  77.00            6.10        4.03
# ...

# %%
high_rev = df_best.loc[df_best['Budget']>=5].sort_values(by='ROI', ascending=False).head(5)
high_rev
# Out:
#                                                                                                                                \
# Title
# E.T. the Extra-Terrestrial  <img src='http://image.tmdb.org/t/p/w185//cBfkE3HSH1NOyy1ftxlPw2l3ukb.jpg' style='height:100px;'>
# My Big Fat Greek Wedding    <img src='http://image.tmdb.org/t/p/w185//3TB2GJqWS9Ro4JdfV6FP87v3etE.jpg' style='height:100px;'>
# Star Wars                   <img src='http://image.tmdb.org/t/p/w185//6FfCtAuVAW8XJjZ7eWeLibRLWTw.jpg' style='height:100px;'>
# Jaws                        <img src='http://image.tmdb.org/t/p/w185//s2xcqSFfT6F7ZXHxowjxfG0yisT.jpg' style='height:100px;'>
# Crocodile Dundee            <img src='http://image.tmdb.org/t/p/w185//kiwOZXU7ddSrWE3ryOQM8sIg1sZ.jpg' style='height:100px;'>
#
#                             Budget  Revenue   Votes  Average Rating  \
# Title
# E.T. the Extra-Terrestrial   10.50   792.97 3359.00            7.30
# ...

# %%
high_rat = df_best.loc[df_best['Votes']>=10].sort_values(by='Average Rating', ascending=False).head(5)
high_rat
# Out:
#                                                                                                                                                                       \
# Title
# Planet Earth II                                                    <img src='http://image.tmdb.org/t/p/w185//gTvArgUjEUDxYMqJHSwVlrn1Cjk.jpg' style='height:100px;'>
# As I Was Moving Ahead Occasionally I Saw Brief Glimpses of Beauty  <img src='http://image.tmdb.org/t/p/w185//k0I65rky3t2HiVciCm1MquV1kSb.jpg' style='height:100px;'>
# The Civil War                                                      <img src='http://image.tmdb.org/t/p/w185//r4sWAokhRr5gYgl5GjzQ8XXCXwI.jpg' style='height:100px;'>
# Cosmos                                                             <img src='http://image.tmdb.org/t/p/w185//mYrnDinyVDhWatHYSwADTTYqoMG.jpg' style='height:100px;'>
# ...

# %%
df_best["Budget"].fillna(0, inplace=True)
df_best["Votes"].fillna(0, inplace=True)
df_best.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44753 entries, Toy Story to Queerama
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0                   44467 non-null  object
#  1   Budget          44753 non-null  float64
#  2   Revenue         7385 non-null   float64
#  3   Votes           44753 non-null  float64
#  4   Average Rating  42097 non-null  float64
#  5   Popularity      44753 non-null  float64
#  6   Profit          5371 non-null   float64
#  7   ROI             5371 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 3.1+ MB

# %%
#Define function to get best and worst movies
def best_worst(n, by, ascending=False, min_budget=0, min_votes=0):
    
    df2 = df_best.loc[(df_best.Budget >=min_budget) & (df_best.Votes>=min_votes),
                      ["", by]].sort_values(by=by, ascending=ascending).head(n).copy()
    
    return HTML(df2.to_html(escape=False))

# %% [markdown]
# __Movies Top 5 - Highest Revenue__

# %%
best_worst(5, by="Revenue")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Revenue</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>2787.97</td>
#     </tr>
#     <tr>
#       <th>Star Wars: The Force Awakens</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'></td>
#       <td>2068.22</td>
#     </tr>
#     <tr>
#       <th>Titanic</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#       <td>1845.03</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
# ...

# %% [markdown]
# __Movies Top 5 - Highest Budget__

# %%
best_worst(5, by="Budget")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Pirates of the Caribbean: On Stranger Tides</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//keGfSvCmYj7CvdRx36OdVrAEibE.jpg' style='height:100px;'></td>
#       <td>380.00</td>
#     </tr>
#     <tr>
#       <th>Pirates of the Caribbean: At World's End</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oVh3REsCwJwmrTkZ9OkkeKiAE02.jpg' style='height:100px;'></td>
#       <td>300.00</td>
#     </tr>
#     <tr>
#       <th>Avengers: Age of Ultron</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg' style='height:100px;'></td>
#       <td>280.00</td>
#     </tr>
#     <tr>
#       <th>Superman Returns</th>
# ...

# %% [markdown]
# __Movies Top 5 - Highest Profit__

# %%
best_worst(5, by="Profit")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Profit</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>2550.97</td>
#     </tr>
#     <tr>
#       <th>Star Wars: The Force Awakens</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'></td>
#       <td>1823.22</td>
#     </tr>
#     <tr>
#       <th>Titanic</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#       <td>1645.03</td>
#     </tr>
#     <tr>
#       <th>Jurassic World</th>
# ...

# %% [markdown]
# __Movies Top 5 - Lowest Profit__

# %%
best_worst(5, by="Profit", ascending=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Profit</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Lone Ranger</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//b2je2ZybNIzAOL1K1WPbbT6zt2M.jpg' style='height:100px;'></td>
#       <td>-165.71</td>
#     </tr>
#     <tr>
#       <th>The Alamo</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//aZrWYkxCCwSPKp4VjVvn46uHbIX.jpg' style='height:100px;'></td>
#       <td>-119.18</td>
#     </tr>
#     <tr>
#       <th>Mars Needs Moms</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lOKqLd0ud1wdwaPK5h6bGNZIVLT.jpg' style='height:100px;'></td>
#       <td>-111.01</td>
#     </tr>
#     <tr>
#       <th>Valerian and the City of a Thousand Planets</th>
# ...

# %% [markdown]
# __Movies Top 5 - Highest ROI__

# %%
best_worst(5, by="ROI", min_budget=5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>E.T. the Extra-Terrestrial</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//cBfkE3HSH1NOyy1ftxlPw2l3ukb.jpg' style='height:100px;'></td>
#       <td>75.52</td>
#     </tr>
#     <tr>
#       <th>My Big Fat Greek Wedding</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//3TB2GJqWS9Ro4JdfV6FP87v3etE.jpg' style='height:100px;'></td>
#       <td>73.75</td>
#     </tr>
#     <tr>
#       <th>Star Wars</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//6FfCtAuVAW8XJjZ7eWeLibRLWTw.jpg' style='height:100px;'></td>
#       <td>70.49</td>
#     </tr>
#     <tr>
#       <th>Jaws</th>
# ...

# %% [markdown]
# __Movies Top 5 - Lowest ROI__

# %%
best_worst(5, by="ROI", ascending=True, min_budget=100)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Adventures of Pluto Nash</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//96vvhLWWDosS1zRrfQ6XEGAzByL.jpg' style='height:100px;'></td>
#       <td>0.07</td>
#     </tr>
#     <tr>
#       <th>The Alamo</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//aZrWYkxCCwSPKp4VjVvn46uHbIX.jpg' style='height:100px;'></td>
#       <td>0.18</td>
#     </tr>
#     <tr>
#       <th>Live by Night</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//bkd46T4RplawnDjpHoI8mhzTLks.jpg' style='height:100px;'></td>
#       <td>0.21</td>
#     </tr>
#     <tr>
#       <th>Mars Needs Moms</th>
# ...

# %% [markdown]
# __Movies Top 5 - Most Votes__

# %%
best_worst(5, by="Votes")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Votes</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Inception</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9gk7adHYeDvHkCSEqAvQNLV5Uge.jpg' style='height:100px;'></td>
#       <td>14075.00</td>
#     </tr>
#     <tr>
#       <th>The Dark Knight</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//qJ2tW6WMUDux911r6m7haRef0WH.jpg' style='height:100px;'></td>
#       <td>12269.00</td>
#     </tr>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>12114.00</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//RYMX2wcKCBAr24UyPD7xwmjaTn.jpg' style='height:100px;'></td>
# ...

# %% [markdown]
# __Movies Top 5 - Highest Rating__

# %%
best_worst(5, by="Average Rating", min_votes=50)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Planet Earth II</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//gTvArgUjEUDxYMqJHSwVlrn1Cjk.jpg' style='height:100px;'></td>
#       <td>9.50</td>
#     </tr>
#     <tr>
#       <th>Dilwale Dulhania Le Jayenge</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2CAL2433ZeIihfX1Hb2139CX0pW.jpg' style='height:100px;'></td>
#       <td>9.10</td>
#     </tr>
#     <tr>
#       <th>Planet Earth</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//koVzjt54bJEVuKTmGC4cExcbE2w.jpg' style='height:100px;'></td>
#       <td>8.80</td>
#     </tr>
#     <tr>
#       <th>Sansho the Bailiff</th>
# ...

# %% [markdown]
# __Movies Top 5 - Lowest Rating__

# %%
best_worst(5, by="Average Rating", ascending=True, min_votes=50)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Manos: The Hands of Fate</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//dcDR1ZhZvA7HQvxQ17hzFjeCNHx.jpg' style='height:100px;'></td>
#       <td>2.00</td>
#     </tr>
#     <tr>
#       <th>Birdemic: Shock and Terror</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lNC2Alq5CIIuPp1Bv0Y8hPHXZlP.jpg' style='height:100px;'></td>
#       <td>2.10</td>
#     </tr>
#     <tr>
#       <th>House of the Dead</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//5jBIUM0tqq8QwNbY8w1RZdU6uWz.jpg' style='height:100px;'></td>
#       <td>2.80</td>
#     </tr>
#     <tr>
#       <th>Back in the Day</th>
# ...

# %%
best_worst(5, by="Average Rating", ascending=True, min_votes=20, min_budget=20)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Foodfight!</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//R1zn75Yz4wpdd85byqhP7mT6No.jpg' style='height:100px;'></td>
#       <td>2.30</td>
#     </tr>
#     <tr>
#       <th>Dragonball Evolution</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//23PcKOqNdhKeMFzORzQGn5eC44N.jpg' style='height:100px;'></td>
#       <td>2.90</td>
#     </tr>
#     <tr>
#       <th>Battlefield Earth</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//wXCRuBHdJ5aTFQdsuGJFXNdo79T.jpg' style='height:100px;'></td>
#       <td>3.00</td>
#     </tr>
#     <tr>
#       <th>Disaster Movie</th>
# ...

# %% [markdown]
# __Movies Top 5 - Most Popular__

# %%
best_worst(5, by="Popularity")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Popularity</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Minions</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tMaGZ2HR8HAFwkx4YRib0CDVfNT.jpg' style='height:100px;'></td>
#       <td>547.49</td>
#     </tr>
#     <tr>
#       <th>Wonder Woman</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//gfJGlDaHuWimErCr5Ql0I8x9QSy.jpg' style='height:100px;'></td>
#       <td>294.34</td>
#     </tr>
#     <tr>
#       <th>Beauty and the Beast</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tWqifoYuwLETmmasnGHO7xBjEtt.jpg' style='height:100px;'></td>
#       <td>287.25</td>
#     </tr>
#     <tr>
#       <th>Baby Driver</th>
# ...

# %% [markdown]
# ## Filter the Dataset for movies that meet the certain conditions:

# %% [markdown]
# __Search 1: Science Fiction Action Movie with Bruce Willis (sorted from high to low Rating)__

# %%
df.genres[0]
# Out:
# 'Animation|Comedy|Family'

# %%
mask_genres = df.genres.str.contains("Action") & df.genres.str.contains("Science Fiction")
mask_genres
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44748    False
# 44749    False
# 44750    False
# 44751    False
# 44752    False
# Name: genres, Length: 44753, dtype: bool

# %%
df.cast[0]
# Out:
# 'Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wallace Shawn|John Ratzenberger|Annie Potts|John Morris|Erik von Detten|Laurie Metcalf|R. Lee Ermey|Sarah Freeman|Penn Jillette'

# %%
mask_actor = df.cast.str.contains("Bruce Willis")
mask_actor
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44748    False
# 44749    False
# 44750    False
# 44751    False
# 44752      NaN
# Name: cast, Length: 44753, dtype: object

# %%
df.loc[mask_actor & mask_genres, ["title", "vote_average"]].sort_values(by= "vote_average", ascending=False)
# Out:
#                        title  vote_average
# 1449       The Fifth Element          7.30
# 19230                 Looper          6.60
# 1788              Armageddon          6.50
# 14142             Surrogates          5.90
# 20346  G.I. Joe: Retaliation          5.40
# 27636                   Vice          4.10

# %%
bruce = df.loc[mask_actor & mask_genres, ["title", "poster_path", "vote_average"]].sort_values(by= "vote_average", ascending=False)

# %%
HTML(bruce.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>poster_path</th>
#       <th>vote_average</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1449</th>
#       <td>The Fifth Element</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//fPtlCO1yQtnoLHOwKtWz7db6RGU.jpg' style='height:100px;'></td>
#       <td>7.30</td>
#     </tr>
#     <tr>
#       <th>19230</th>
#       <td>Looper</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//sNjL6SqErDBE8OUZlrDLkexfsCj.jpg' style='height:100px;'></td>
#       <td>6.60</td>
#     </tr>
#     <tr>
#       <th>1788</th>
#       <td>Armageddon</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//fMtOCd0EAdAzKtGLQiHjSUvbdNc.jpg' style='height:100px;'></td>
#       <td>6.50</td>
#     </tr>
#     <tr>
#       <th>14142</th>
#       <td>Surrogates</td>
# ...

# %% [markdown]
# __Search 2: Movies with Uma Thurman and directed by Quentin Tarantino (sorted from short to long runtime)__

# %%
mask_cast = df.cast.str.contains("Uma Thurman")
mask_director = df.director == "Quentin Tarantino"

# %%
uma_quentin = df.loc[mask_cast & mask_director, ["title", "poster_path", "runtime"]].sort_values(by="runtime").set_index("title")
HTML(uma_quentin.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>runtime</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Kill Bill: Vol. 1</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//v7TaX8kXMXs5yFFGR41guUDNcnB.jpg' style='height:100px;'></td>
#       <td>111.00</td>
#     </tr>
#     <tr>
#       <th>Kill Bill: Vol. 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2yhg0mZQMhDyvUQ4rG1IZ4oIA8L.jpg' style='height:100px;'></td>
#       <td>136.00</td>
#     </tr>
#     <tr>
#       <th>Pulp Fiction</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//d5iIlFn5s0ImszYzBPb8JPIfbXD.jpg' style='height:100px;'></td>
#       <td>154.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Search 3: Most Successful Pixar Studio Movies between 2010 and 2015 (sorted from high to low Revenue)__

# %%
df.columns
# Out:
# Index(['id', 'title', 'tagline', 'release_date', 'genres',
#        'belongs_to_collection', 'original_language', 'budget_musd',
#        'revenue_musd', 'production_companies', 'production_countries',
#        'vote_count', 'vote_average', 'popularity', 'runtime', 'overview',
#        'spoken_languages', 'poster_path', 'cast', 'cast_size', 'crew_size',
#        'director'],
#       dtype='object')

# %%
df.production_companies
# Out:
# 0                                        Pixar Animation Studios
# 1        TriStar Pictures|Teitler Film|Interscope Communications
# 2                                    Warner Bros.|Lancaster Gate
# 3                         Twentieth Century Fox Film Corporation
# 4                      Sandollar Productions|Touchstone Pictures
#                                   ...
# 44748                                                        NaN
# 44749                                                Sine Olivia
# 44750                                    American World Pictures
# 44751                                                  Yermoliev
# 44752                                                        NaN
# Name: production_companies, Length: 44753, dtype: object

# %%
mask_studio = df.production_companies.str.contains("Pixar").fillna(False)

# %%
mask_time = df.release_date.between("2010-01-01", "2015-12-31")

# %%
pixar = df.loc[mask_studio & mask_time, ["title", "poster_path", "revenue_musd", "release_date"]].sort_values(by="revenue_musd", ascending=False).set_index("title")
HTML(pixar.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>revenue_musd</th>
#       <th>release_date</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Toy Story 3</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//amY0NH1ksd9xJ9boXAMmods6U0D.jpg' style='height:100px;'></td>
#       <td>1066.97</td>
#       <td>2010-06-16</td>
#     </tr>
#     <tr>
#       <th>Inside Out</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lRHE0vzf3oYJrhbsHXjIkF4Tl5A.jpg' style='height:100px;'></td>
#       <td>857.61</td>
#       <td>2015-06-09</td>
#     </tr>
#     <tr>
#       <th>Monsters University</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tyHHjZEzJutWggujN1KP0a1jfLX.jpg' style='height:100px;'></td>
#       <td>743.56</td>
#       <td>2013-06-20</td>
#     </tr>
# ...

# %% [markdown]
# __Search 4: Action or Thriller Movie with original language English and minimum Rating of 7.5 (most recent movies first)__

# %%
mask_genres = df.genres.str.contains("Action") | df.genres.str.contains("Thriller") 
mask_language = df.original_language.str.contains("en")
mask_rating = df.vote_average >= 7.5
mask_vote = df.vote_count >= 10

# %%
action = df.loc[mask_genres & mask_language & mask_rating & mask_vote, 
                ["title", "poster_path", "genres", "vote_average", "vote_count", "release_date"]].sort_values(by="release_date", ascending=False).set_index("title")

# %%
HTML(action.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>genres</th>
#       <th>vote_average</th>
#       <th>vote_count</th>
#       <th>release_date</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Descendants 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//8BNyZlBk4Hs92z6UrvFDjvx3yMb.jpg' style='height:100px;'></td>
#       <td>TV Movie|Family|Action|Comedy|Music|Adventure</td>
#       <td>7.50</td>
#       <td>171.00</td>
#       <td>2017-07-21</td>
#     </tr>
#     <tr>
#       <th>Dunkirk</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//ebSnODDg9lbsMIaWg2uAbjn7TO5.jpg' style='height:100px;'></td>
#       <td>Action|Drama|History|Thriller|War</td>
#       <td>7.50</td>
#       <td>2712.00</td>
# ...

# %% [markdown]
# ## Most common Words in Movie Titles and Taglines

# %%
from wordcloud import WordCloud

# %%
df.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                                                           tagline  \
# 0                                                                             NaN
# 1                                       Roll the dice and unleash the excitement!
# 2                            Still Yelling. Still Fighting. Still Ready for Love.
# 3  Friends are the people who let you be yourself... and never let you forget it.
# 4  Just When His World Is Back To Normal... He's In For The Surprise Of His Life!
#
#   release_date                    genres           belongs_to_collection  \
# 0   1995-10-30   Animation|Comedy|Family            Toy Story Collection
# 1   1995-12-15  Adventure|Fantasy|Family                             NaN
# ...

# %%
df.title[1]
# Out:
# 'Jumanji'

# %%
df.tagline[1]
# Out:
# 'Roll the dice and unleash the excitement!'

# %%
df.overview[1]
# Out:
# "When siblings Judy and Peter discover an enchanted board game that opens the door to a magical world, they unwittingly invite Alan -- an adult who's been trapped inside the game for 26 years -- into their living room. Alan's only hope for freedom is to finish the game, which proves risky as all three find themselves running from giant rhinoceroses, evil monkeys and other terrifying creatures."

# %%
title = df.title.dropna()
tagline = df.tagline.dropna()
overview = df.overview.dropna()

# %%
title
# Out:
# 0                          Toy Story
# 1                            Jumanji
# 2                   Grumpier Old Men
# 3                  Waiting to Exhale
# 4        Father of the Bride Part II
#                     ...
# 44748                         Subdue
# 44749            Century of Birthing
# 44750                       Betrayal
# 44751               Satan Triumphant
# 44752                       Queerama
# Name: title, Length: 44753, dtype: object

# %%
title_corpus = ' '.join(title)
tagline_corpus = ' '.join(tagline)
overview_corpus = ' '.join(overview)

# %%
title_wordcloud = WordCloud(background_color='white', height=2000, width=4000, max_words=200).generate(title_corpus)
title_wordcloud

# %%
plt.figure(figsize=(16,8))
plt.imshow(title_wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
tagline_wordcloud = WordCloud(background_color='white', height=2000, width=4000, max_words=200).generate(tagline_corpus)
plt.figure(figsize=(16,8))
plt.imshow(tagline_wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
overview_wordcloud = WordCloud(background_color='white', height=2000, width=4000, max_words=200).generate(overview_corpus)
plt.figure(figsize=(16,8))
plt.imshow(overview_wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# ## Are Franchises more successful than stand-alone movies? In terms of:
#
# - mean revenue
# - median Return on Investment
# - mean budget raised
# - mean popularity
# - mean rating

# %%
df.belongs_to_collection
# Out:
# 0                  Toy Story Collection
# 1                                   NaN
# 2             Grumpy Old Men Collection
# 3                                   NaN
# 4        Father of the Bride Collection
#                       ...
# 44748                               NaN
# 44749                               NaN
# 44750                               NaN
# 44751                               NaN
# 44752                               NaN
# Name: belongs_to_collection, Length: 44753, dtype: object

# %%
df["Franchise"] = df.belongs_to_collection.notna()
df.Franchise
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 44748    False
# 44749    False
# 44750    False
# 44751    False
# 44752    False
# Name: Franchise, Length: 44753, dtype: bool

# %%
df.Franchise.value_counts()
# Out:
# False    40290
# True      4463
# Name: Franchise, dtype: int64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Revenue__

# %%
df.groupby("Franchise")["revenue_musd"].mean()
# Out:
# Franchise
# False    44.74
# True    165.71
# Name: revenue_musd, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Return on Investment / Profitability (median)__

# %%
df["ROI"] = df.revenue_musd.div(df.budget_musd)
df.groupby("Franchise")["ROI"].median()
# Out:
# Franchise
# False   1.62
# True    3.71
# Name: ROI, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Budget__

# %%
df.groupby("Franchise")["budget_musd"].mean()
# Out:
# Franchise
# False   18.05
# True    38.32
# Name: budget_musd, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Popularity__

# %%
df.groupby("Franchise")["popularity"].mean()
# Out:
# Franchise
# False   2.59
# True    6.25
# Name: popularity, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Rating__

# %%
df.groupby("Franchise")["vote_average"].mean()
# Out:
# Franchise
# False   6.01
# True    5.96
# Name: vote_average, dtype: float64

# %%
df.groupby("Franchise").agg({"revenue_musd": "mean", "ROI": "median", "budget_musd": "mean", 
                             "popularity": "mean", "vote_average": "mean"})
# Out:
#            revenue_musd  ROI  budget_musd  popularity  vote_average
# Franchise
# False             44.74 1.62        18.05        2.59          6.01
# True             165.71 3.71        38.32        6.25          5.96

# %% [markdown]
# ## Most Successful Franchises in terms of:
#
# - __total number of movies__
# - __total & mean budget__
# - __total & mean revenue__
# - __mean rating__

# %%
df.belongs_to_collection.value_counts()
# Out:
# The Bowery Boys                  29
# Totò Collection                  27
# Zatôichi: The Blind Swordsman    26
# James Bond Collection            26
# The Carry On Collection          25
#                                  ..
# Salt and Pepper Collection        1
# Deadpool Collection               1
# Ant-Man Collection                1
# Elvira Collection                 1
# Red Lotus Collection              1
# Name: belongs_to_collection, Length: 1691, dtype: int64

# %%
franchises = df.groupby("belongs_to_collection").agg({"title":"count", "budget_musd": ["sum", "mean"], 
                                        "revenue_musd": ["sum", "mean"], "vote_average": "mean", "popularity": "mean",
                                        "ROI": "median", "vote_count": "mean"})

# %%
franchises
# Out:
#                                      title budget_musd       revenue_musd  \
#                                      count         sum  mean          sum
# belongs_to_collection
# ... Has Fallen Collection                2      130.00 65.00       366.78
# 00 Schneider Filmreihe                   1        0.00   NaN         0.00
# 08/15 Collection                         1        0.00   NaN         0.00
# 100 Girls Collection                     2        0.00   NaN         0.00
# 101 Dalmatians (Animated) Collection     2        4.00  4.00       215.88
# ...                                    ...         ...   ...          ...
# Сказки Чуковского                        1        0.00   NaN         0.00
# Чебурашка и крокодил Гена                1        0.00   NaN         0.00
# Что Творят мужчины! (Коллекция)          2        2.00  2.00         0.00
# 男はつらいよ シリーズ                              3        0.00   NaN         0.00
# ...

# %%
franchises.nlargest(20, ("title", "count"))
# Out:
#                                        title budget_musd       revenue_musd  \
#                                        count         sum  mean          sum
# belongs_to_collection
# The Bowery Boys                           29        0.00   NaN         0.00
# Totò Collection                           27        0.00   NaN         0.00
# James Bond Collection                     26     1539.65 59.22      7106.97
# Zatôichi: The Blind Swordsman             26        0.00   NaN         0.00
# The Carry On Collection                   25        0.00   NaN         0.00
# Charlie Chan (Sidney Toler) Collection    21        0.00   NaN         0.00
# Pokémon Collection                        20      250.72 50.14       601.87
# Godzilla (Showa) Collection               16        2.81  0.56         0.00
# Charlie Chan (Warner Oland) Collection    15        0.00   NaN         0.00
# Dragon Ball Z (Movie) Collection          15        5.00  5.00       112.12
# ...

# %%
franchises.nlargest(20, ("revenue_musd", "mean"))
# Out:
#                                     title budget_musd        revenue_musd  \
#                                     count         sum   mean          sum
# belongs_to_collection
# Avatar Collection                       1      237.00 237.00      2787.97
# The Avengers Collection                 2      500.00 250.00      2924.96
# Frozen Collection                       2      150.00 150.00      1274.22
# Finding Nemo Collection                 2      294.00 147.00      1968.91
# The Hobbit Collection                   3      750.00 250.00      2935.52
# The Lord of the Rings Collection        3      266.00  88.67      2916.54
# Harry Potter Collection                 8     1280.00 160.00      7707.37
# Star Wars Collection                    8      854.35 106.79      7434.49
# Despicable Me Collection                6      299.00  74.75      3691.07
# Pirates of the Caribbean Collection     5     1250.00 250.00      4521.58
# ...

# %%
franchises.nlargest(20, ("budget_musd", "mean"))
# Out:
#                                         title budget_musd        revenue_musd  \
#                                         count         sum   mean          sum
# belongs_to_collection
# Tangled Collection                          2      260.00 260.00       591.79
# Pirates of the Caribbean Collection         5     1250.00 250.00      4521.58
# The Avengers Collection                     2      500.00 250.00      2924.96
# The Hobbit Collection                       3      750.00 250.00      2935.52
# Man of Steel Collection                     2      475.00 237.50      1536.11
# Avatar Collection                           1      237.00 237.00      2787.97
# The Amazing Spider-Man Collection           2      415.00 207.50      1457.93
# World War Z Collection                      1      200.00 200.00       531.87
# Spider-Man Collection                       3      597.00 199.00      2496.35
# The Dark Knight Collection                  3      585.00 195.00      2463.72
# ...

# %%
franchises[franchises[("vote_count", "mean")] >= 1000].nlargest(20, ("vote_average", "mean"))
# Out:
#                                     title budget_musd        revenue_musd  \
#                                     count         sum   mean          sum
# belongs_to_collection
# The Lord of the Rings Collection        3      266.00  88.67      2916.54
# The Godfather Collection                3       73.00  24.33       429.38
# Blade Runner Collection                 1       28.00  28.00        33.14
# The Man With No Name Collection         3        2.00   0.67        35.50
# The Dark Knight Collection              3      585.00 195.00      2463.72
# Guardians of the Galaxy Collection      2      370.00 185.00      1636.74
# Kill Bill Collection                    2       60.00  30.00       333.11
# Kingsman Collection                     1       81.00  81.00       414.35
# How to Train Your Dragon Collection     2      310.00 155.00      1104.00
# Harry Potter Collection                 8     1280.00 160.00      7707.37
# ...

# %% [markdown]
# ## Most Successful Directors in terms of:
# - __total number of movies__
# - __total revenue__
# - __mean rating__

# %%
df.director
# Out:
# 0           John Lasseter
# 1            Joe Johnston
# 2           Howard Deutch
# 3         Forest Whitaker
# 4           Charles Shyer
#                ...
# 44748    Hamid Nematollah
# 44749            Lav Diaz
# 44750      Mark L. Lester
# 44751    Yakov Protazanov
# 44752       Daisy Asquith
# Name: director, Length: 44753, dtype: object

# %%
df.director.value_counts().head(20)
# Out:
# John Ford             66
# Michael Curtiz        65
# Werner Herzog         54
# Alfred Hitchcock      53
# Georges Méliès        49
# Woody Allen           49
# Jean-Luc Godard       46
# Sidney Lumet          46
# Charlie Chaplin       44
# Raoul Walsh           43
# William A. Wellman    42
# Henry Hathaway        41
# Richard Thorpe        40
# Ingmar Bergman        39
# Martin Scorsese       39
# Fritz Lang            38
# John Huston           38
# George Cukor          38
# Robert Altman         37
# Mervyn LeRoy          37
# Name: director, dtype: int64

# %%
plt.figure(figsize = (12,8))
df.director.value_counts().head(20).plot(kind='bar', fontsize=15, rot=45)
plt.title("Most Successful Directors", fontsize=20)
plt.ylabel("Number of movies", fontsize=15)
plt.show()

# %%
df.groupby("director").revenue_musd.sum().nlargest(20)
# Out:
# director
# Steven Spielberg    9256.62
# Peter Jackson       6528.24
# Michael Bay         6437.47
# James Cameron       5900.61
# David Yates         5334.56
# Christopher Nolan   4747.41
# Robert Zemeckis     4138.23
# Tim Burton          4032.92
# Ridley Scott        3917.53
# Chris Columbus      3866.84
# Roland Emmerich     3798.40
# Ron Howard          3714.15
# J.J. Abrams         3579.22
# Gore Verbinski      3575.34
# George Lucas        3341.55
# Sam Raimi           3193.79
# Francis Lawrence    3183.34
# Clint Eastwood      3100.68
# Bill Condon         3017.30
# Joss Whedon         2963.83
# Name: revenue_musd, dtype: float64

# %%
plt.figure(figsize = (12,8))
df.groupby("director").revenue_musd.sum().nlargest(20).plot(kind='bar', fontsize=15, rot=45)
plt.title("Most Successful Directors", fontsize=20)
plt.ylabel("Revenue (in MUSD)", fontsize=15)
plt.show()

# %%
directors = df.groupby("director").agg({"title": "count", "vote_average": "mean", "vote_count": "sum"})

# %%
directors
# Out:
#                      title  vote_average  vote_count
# director
#  Dale Trevillion\t       2          4.00        4.00
#  Davide Manuli           1          6.90       10.00
#  E.W. Swackhamer         1          5.90        5.00
#  Vitaliy Vorobyov        1          5.50        3.00
#  Yeon Sang-Ho            4          6.60     1039.00
# ...                    ...           ...         ...
# Ярополк Лапшин           1         10.00        1.00
# پیمان معادی              1          6.00        2.00
# 塩谷 直義                    1          7.20       40.00
# 杰森·莫玛                    1          5.80       28.00
# 진모영                      1          6.00        6.00
#
# [17369 rows x 3 columns]

# %%
directors[(directors.vote_count >= 10000) & (directors.title >= 10)].nlargest(20, "vote_average")
# Out:
#                    title  vote_average  vote_count
# director
# Hayao Miyazaki        14          7.70    14700.00
# Christopher Nolan     11          7.62    67344.00
# Quentin Tarantino     10          7.49    45910.00
# Wes Anderson          10          7.37    11743.00
# David Fincher         10          7.35    37588.00
# Martin Scorsese       39          7.22    35541.00
# Peter Jackson         13          7.14    47571.00
# Joel Coen             17          7.02    18139.00
# James Cameron         11          6.93    33736.00
# Stanley Kubrick       16          6.91    18214.00
# James Mangold         10          6.90    16607.00
# Steven Spielberg      33          6.89    62266.00
# Danny Boyle           14          6.87    16504.00
# Guy Ritchie           10          6.80    19626.00
# Robert Zemeckis       19          6.79    37666.00
# Terry Gilliam         14          6.76    10049.00
# Tim Burton            21          6.73    36922.00
# ...

# %%
df.genres = df.genres.astype("str")

# %%
df.loc[df.genres.str.contains("Horror")].groupby("director").revenue_musd.sum().nlargest(20)
# Out:
# director
# Paul W.S. Anderson    982.29
# James Wan             861.31
# Wes Craven            834.93
# Francis Lawrence      816.23
# Ridley Scott          689.00
# Marc Forster          531.87
# Steven Spielberg      500.10
# William Friedkin      466.40
# Darren Lynn Bousman   456.34
# M. Night Shyamalan    375.37
# Henry Joost           349.07
# David R. Ellis        348.74
# Adrian Lyne           346.11
# James DeMonaco        316.70
# Stephen Sommers       311.46
# Gore Verbinski        275.91
# Guillermo del Toro    261.63
# John R. Leonetti      255.27
# Fede Alvarez          254.64
# Jordan Peele          252.43
# Name: revenue_musd, dtype: float64

# %% [markdown]
# ## Most Successful Actors

# %%
df.set_index("id", inplace=True)

# %%
df.cast
# Out:
# id
# 862                                    Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wallace Shawn|John Ratzenberger|Annie Potts|John Morris|Erik von Detten|Laurie Metcalf|R. Lee Ermey|Sarah Freeman|Penn Jillette
# 8844      Robin Williams|Jonathan Hyde|Kirsten Dunst|Bradley Pierce|Bonnie Hunt|Bebe Neuwirth|David Alan Grier|Patricia Clarkson|Adam Hann-Byrd|Laura Bell Bundy|James Handy|Gillian Barber|Brandon Obray|Cyru...
# 15602                                                                                                              Walter Matthau|Jack Lemmon|Ann-Margret|Sophia Loren|Daryl Hannah|Burgess Meredith|Kevin Pollak
# 31357                                                       Whitney Houston|Angela Bassett|Loretta Devine|Lela Rochon|Gregory Hines|Dennis Haysbert|Michael Beach|Mykelti Williamson|Lamont Johnson|Wesley Snipes
# ...

# %%
act = df.cast.str.split("|", expand=True)
act
# Out:
#                      0                  1               2    \
# id
# 862            Tom Hanks          Tim Allen     Don Rickles
# 8844      Robin Williams      Jonathan Hyde   Kirsten Dunst
# 15602     Walter Matthau        Jack Lemmon     Ann-Margret
# 31357    Whitney Houston     Angela Bassett  Loretta Devine
# 11862       Steve Martin       Diane Keaton    Martin Short
# ...                  ...                ...             ...
# 439050      Leila Hatami     Kourosh Tahami     Elham Korda
# 111109      Angel Aquino        Perry Dizon   Hazel Orencio
# 67758      Erika Eleniak       Adam Baldwin   Julie du Page
# 227506  Iwan Mosschuchin  Nathalie Lissenko    Pavel Pavlov
# 461257               NaN                NaN             NaN
#
#                               3               4                  5    \
# id
# 862                    Jim Varney   Wallace Shawn  John Ratzenberger
# 8844               Bradley Pierce     Bonnie Hunt      Bebe Neuwirth
# ...

# %%
act = act.stack().reset_index(1, drop=True).to_frame()
act
# Out:
#                         0
# id
# 862             Tom Hanks
# 862             Tim Allen
# 862           Don Rickles
# 862            Jim Varney
# 862         Wallace Shawn
# ...                   ...
# 227506   Iwan Mosschuchin
# 227506  Nathalie Lissenko
# 227506       Pavel Pavlov
# 227506  Aleksandr Chabrov
# 227506        Vera Orlova
#
# [557796 rows x 1 columns]

# %%
act.columns = ["Actor"]
act
# Out:
#                     Actor
# id
# 862             Tom Hanks
# 862             Tim Allen
# 862           Don Rickles
# 862            Jim Varney
# 862         Wallace Shawn
# ...                   ...
# 227506   Iwan Mosschuchin
# 227506  Nathalie Lissenko
# 227506       Pavel Pavlov
# 227506  Aleksandr Chabrov
# 227506        Vera Orlova
#
# [557796 rows x 1 columns]

# %%
act = act.merge(df[["title", "revenue_musd", "vote_average", "popularity"]], 
                how="left", left_index = True, right_index=True)
act
# Out:
#                      Actor                            title  revenue_musd  \
# id
# 2              Turo Pajala                            Ariel           NaN
# 2         Susanna Haavisto                            Ariel           NaN
# 2          Matti Pellonpää                            Ariel           NaN
# 2             Eetu Hilkamo                            Ariel           NaN
# 3          Matti Pellonpää              Shadows in Paradise           NaN
# ...                    ...                              ...           ...
# 469172      Vasco Sequeira  Manuel on the Island of Wonders           NaN
# 469172     Armanda Bacelar  Manuel on the Island of Wonders           NaN
# 469172     Rafael de Sousa  Manuel on the Island of Wonders           NaN
# 469172  José Antônio Gomes  Manuel on the Island of Wonders           NaN
# 469172       Isabel Branco  Manuel on the Island of Wonders           NaN
#
#         vote_average  popularity
# id
# 2               7.10        3.86
# ...

# %%
act.Actor.nunique()
# Out:
# 201514

# %%
act.Actor.unique()
# Out:
# array(['Turo Pajala', 'Susanna Haavisto', 'Matti Pellonpää', ...,
#        'Armanda Bacelar', 'Rafael de Sousa', 'José Antônio Gomes'],
#       dtype=object)

# %%
act.Actor.value_counts().head(20)
# Out:
# Bess Flowers          240
# Christopher Lee       148
# John Wayne            125
# Samuel L. Jackson     122
# Michael Caine         110
# John Carradine        109
# Gérard Depardieu      109
# Donald Sutherland     108
# Jackie Chan           108
# Frank Welker          107
# Robert De Niro        104
# Steve Buscemi         101
# Danny Trejo           101
# Irving Bacon           98
# John Goodman           97
# Christopher Walken     96
# Danny Glover           95
# John Hurt              93
# Susan Sarandon         92
# Dennis Hopper          92
# Name: Actor, dtype: int64

# %%
plt.figure(figsize = (12,8))
act.Actor.value_counts().head(20).plot(kind='bar', fontsize=15, rot=45)
plt.title("Most Active Actor", fontsize=20)
plt.ylabel("Number of movies", fontsize=15)
plt.show()

# %%
agg = act.groupby("Actor").agg(Total_Revenue=("revenue_musd", "sum"),
                              Mean_Revenue = ("revenue_musd", "mean"),
                               Mean_Rating = ("vote_average", "mean"),
                               Mean_Pop = ("popularity", "mean"),
                               Total_Movies = ("Actor", "count"))

# %%
agg.nlargest(20, "Total_Movies")
# Out:
#                     Total_Revenue  Mean_Revenue  Mean_Rating  Mean_Pop  \
# Actor
# Bess Flowers               368.91         14.76         6.18      2.03
# Christopher Lee           9417.05        324.73         5.91      4.75
# John Wayne                 236.09         11.24         5.71      3.09
# Samuel L. Jackson        17109.62        213.87         6.27     11.70
# Michael Caine             8053.40        191.75         6.27      8.27
# Gérard Depardieu          1247.61         95.97         6.05      3.70
# John Carradine             255.84         19.68         5.55      2.43
# Donald Sutherland         5390.77        138.22         6.23      7.00
# Jackie Chan               4699.19        146.85         6.28      5.86
# Frank Welker             13044.15        326.10         6.31      9.57
# Robert De Niro            5877.09         81.63         6.43      8.71
# Danny Trejo               2572.23         73.49         5.19      5.74
# ...

# %%
agg.nlargest(20, "Total_Revenue")
# Out:
#                    Total_Revenue  Mean_Revenue  Mean_Rating  Mean_Pop  \
# Actor
# Stan Lee                19414.96        647.17         6.51     29.94
# Samuel L. Jackson       17109.62        213.87         6.27     11.70
# Warwick Davis           13256.03        662.80         6.29     13.09
# Frank Welker            13044.15        326.10         6.31      9.57
# John Ratzenberger       12596.13        449.86         6.48     10.96
# Jess Harnell            12234.61        611.73         6.44     10.92
# Hugo Weaving            11027.58        459.48         6.47     10.97
# Ian McKellen            11015.59        478.94         6.35     15.45
# Johnny Depp             10653.76        217.42         6.44     12.38
# Alan Rickman            10612.63        353.75         6.72     10.40
# Gary Oldman             10534.77        292.63         6.51     13.83
# Alan Tudyk              10276.76        367.03         6.50     16.07
# ...

# %%
plt.figure(figsize = (12,8))
agg.Total_Revenue.nlargest(10).plot(kind='bar', fontsize=15, rot=45)
plt.title("Total Revenue", fontsize=20)
plt.ylabel("Revenue (in MUSD)", fontsize=15)
plt.show()

# %%
agg.Mean_Revenue.nlargest(20)
# Out:
# Actor
# April Marie Thomas   2787.97
# Ashley Jeffery       2787.97
# Austin Wilson        2787.97
# Brandon Jelkes       2787.97
# Bravita A. Threatt   2787.97
# Carvon Futrell       2787.97
# Chris Mala           2787.97
# Christa Oliver       2787.97
# Christopher Nolen    2787.97
# Colin Bleasdale      2787.97
# Cullen B. Madden     2787.97
# David Van Horn       2787.97
# Frankie Torres       2787.97
# Gerry Blair          2787.97
# Hanniyah Muhammad    2787.97
# James Patrick Pitt   2787.97
# Jamie Harrison       2787.97
# Jason Whyte          2787.97
# Jodie Landau         2787.97
# Jodie Taylor         2787.97
# Name: Mean_Revenue, dtype: float64

# %%
act[act.Actor == "Ashley Jeffery" ]
# Out:
#                 Actor   title  revenue_musd  vote_average  popularity
# id
# 19995  Ashley Jeffery  Avatar       2787.97          7.20      185.07

# %%
agg[agg["Total_Movies"] >= 25].nlargest(10, "Mean_Revenue")
# Out:
#                Total_Revenue  Mean_Revenue  Mean_Rating  Mean_Pop  \
# Actor
# Warwick Davis       13256.03        662.80         6.29     13.09
# Stan Lee            19414.96        647.17         6.51     29.94
# Jess Harnell        12234.61        611.73         6.44     10.92
# Andy Serkis         10255.27        569.74         6.49     15.81
# Orlando Bloom        9387.82        552.22         6.49     18.98
# Julie Walters        8726.02        545.38         6.69      9.50
# Ian McKellen        11015.59        478.94         6.35     15.45
# David Bradley        7363.98        460.25         6.31      8.58
# Hugo Weaving        11027.58        459.48         6.47     10.97
# Frank Oz             8237.09        457.62         6.79      9.65
#
#                Total_Movies
# Actor
# Warwick Davis            34
# Stan Lee                 48
# Jess Harnell             35
# Andy Serkis              41
# Orlando Bloom            29
# Julie Walters            33
# ...

# %%
agg[agg["Total_Movies"] >= 25].nlargest(20, "Mean_Rating")
# Out:
#                      Total_Revenue  Mean_Revenue  Mean_Rating  Mean_Pop  \
# Actor
# Maaya Sakamoto              128.58         21.43         7.34      3.84
# Toshirō Mifune               32.12         10.71         7.23      3.99
# Tatsuya Nakadai               4.34          2.17         7.19      3.19
# Eijirô Tôno                  29.82         14.91         7.09      2.85
# Chishu Ryu                    0.50          0.50         7.08      1.43
# Kouichi Yamadera            314.02         31.40         7.05      6.00
# Martin Scorsese             800.29         88.92         7.05      3.94
# Werner Herzog               788.19        112.60         7.04      3.18
# Philip Ettington           6105.41        174.44         7.02     15.61
# Arthur Tovey               1007.31         71.95         7.00      8.49
# Jean-Pierre Léaud            51.33          8.56         6.97      3.48
# Tony Leung Chiu-Wai         531.32         66.42         6.96      5.19
# ...

# %%
agg[agg["Total_Movies"] >= 25].nlargest(20, "Mean_Pop")
# Out:
#                 Total_Revenue  Mean_Revenue  Mean_Rating  Mean_Pop  \
# Actor
# Jon Hamm              3449.35        191.63         6.33     39.42
# Stan Lee             19414.96        647.17         6.51     29.94
# Geoffrey Rush         8531.13        304.68         6.57     26.35
# Steve Carell          6979.52        240.67         6.26     25.93
# Sandra Bullock        4902.16        181.56         5.99     22.49
# Zoe Saldana           7206.98        300.29         6.46     21.11
# Steve Coogan          6425.94        257.04         6.07     20.78
# Chris Pine            3326.37        158.40         6.35     20.57
# Jeremy Renner         7484.33        325.41         6.45     20.00
# Chris Pratt           4957.21        260.91         6.23     19.90
# Michael Keaton        4789.68        177.40         6.12     19.33
# Orlando Bloom         9387.82        552.22         6.49     18.98
# Chris Evans           7071.16        294.63         6.38     18.58
# ...

# %% [markdown]
# ## Most successful/popular genres

# %%
df.columns
# Out:
# Index(['title', 'tagline', 'release_date', 'genres', 'belongs_to_collection',
#        'original_language', 'budget_musd', 'revenue_musd',
#        'production_companies', 'production_countries', 'vote_count',
#        'vote_average', 'popularity', 'runtime', 'overview', 'spoken_languages',
#        'poster_path', 'cast', 'cast_size', 'crew_size', 'director',
#        'Franchise', 'ROI'],
#       dtype='object')

# %%
df.genres
# Out:
# id
# 862        Animation|Comedy|Family
# 8844      Adventure|Fantasy|Family
# 15602               Romance|Comedy
# 31357         Comedy|Drama|Romance
# 11862                       Comedy
#                     ...
# 439050                Drama|Family
# 111109                       Drama
# 67758        Action|Drama|Thriller
# 227506                         nan
# 461257                         nan
# Name: genres, Length: 44753, dtype: object

# %%
gen = df.genres.str.split("|", expand=True)
gen
# Out:
#                 0        1         2     3     4     5     6     7
# id
# 862     Animation   Comedy    Family  None  None  None  None  None
# 8844    Adventure  Fantasy    Family  None  None  None  None  None
# 15602     Romance   Comedy      None  None  None  None  None  None
# 31357      Comedy    Drama   Romance  None  None  None  None  None
# 11862      Comedy     None      None  None  None  None  None  None
# ...           ...      ...       ...   ...   ...   ...   ...   ...
# 439050      Drama   Family      None  None  None  None  None  None
# 111109      Drama     None      None  None  None  None  None  None
# 67758      Action    Drama  Thriller  None  None  None  None  None
# 227506        nan     None      None  None  None  None  None  None
# 461257        nan     None      None  None  None  None  None  None
#
# [44753 rows x 8 columns]

# %%
gen = gen.stack().reset_index(1, drop=True).to_frame()
gen
# Out:
#                 0
# id
# 862     Animation
# 862        Comedy
# 862        Family
# 8844    Adventure
# 8844      Fantasy
# ...           ...
# 67758      Action
# 67758       Drama
# 67758    Thriller
# 227506        nan
# 461257        nan
#
# [92393 rows x 1 columns]

# %%
gen.columns = ["Genre"]

# %%
gen = gen.merge(df[["title", "revenue_musd", "vote_average", "popularity", "release_date", "vote_count"]], 
                how="left", left_index = True, right_index=True)
gen
# Out:
#           Genre                             title  revenue_musd  vote_average  \
# id
# 2         Drama                             Ariel           NaN          7.10
# 2         Crime                             Ariel           NaN          7.10
# 3         Drama               Shadows in Paradise           NaN          7.10
# 3        Comedy               Shadows in Paradise           NaN          7.10
# 5         Crime                        Four Rooms          4.30          6.50
# ...         ...                               ...           ...           ...
# 468343  Romance          Silja - nuorena nukkunut           NaN           NaN
# 468707  Romance  Thick Lashes of Lauri Mäntyvaara           NaN          8.00
# 468707   Comedy  Thick Lashes of Lauri Mäntyvaara           NaN          8.00
# 469172  Fantasy   Manuel on the Island of Wonders           NaN           NaN
# 469172    Drama   Manuel on the Island of Wonders           NaN           NaN
#
# ...

# %%
agg_gen = gen.groupby("Genre").agg(Total_Revenue=("revenue_musd", "sum"),
                            Mean_Revenue = ("revenue_musd", "mean"),
                            Mean_Rating = ("vote_average", "mean"),
                            Mean_Pop = ("popularity", "mean"),
                            Total_Movies = ("Genre", "count"))
agg_gen
# Out:
#                  Total_Revenue  Mean_Revenue  Mean_Rating  Mean_Pop  \
# Genre
# Action               201388.05        116.07         5.75      4.78
# Adventure            199978.67        179.19         5.88      6.00
# Animation             67432.97        176.99         6.45      4.75
# Comedy               166845.05         64.10         5.97      3.25
# Crime                 63375.73         58.52         6.10      4.15
# Documentary            1449.11          6.65         6.66      0.96
# Drama                160754.36         43.83         6.17      3.03
# Family               107076.78        159.10         5.93      4.77
# Fantasy              103920.15        166.01         5.93      5.36
# Foreign                 291.54          3.51         5.97      0.77
# History               14902.20         50.52         6.41      3.48
# Horror                30837.09         41.96         5.31      3.58
# Music                 13370.29         50.08         6.33      2.56
# ...

# %%
agg_gen.nlargest(10, "Total_Movies")
# Out:
#                  Total_Revenue  Mean_Revenue  Mean_Rating  Mean_Pop  \
# Genre
# Drama                160754.36         43.83         6.17      3.03
# Comedy               166845.05         64.10         5.97      3.25
# Thriller             129724.55         69.52         5.74      4.51
# Romance               73473.19         51.27         6.04      3.14
# Action               201388.05        116.07         5.75      4.78
# Horror                30837.09         41.96         5.31      3.58
# Crime                 63375.73         58.52         6.10      4.15
# Documentary            1449.11          6.65         6.66      0.96
# Adventure            199978.67        179.19         5.88      6.00
# Science Fiction       97847.96        131.52         5.48      5.00
#
#                  Total_Movies
# Genre
# Drama                   20056
# Comedy                  13069
# Thriller                 7565
# Romance                  6662
# Action                   6542
# ...

# %%
agg_gen.nlargest(10, "Mean_Revenue")
# Out:
#                  Total_Revenue  Mean_Revenue  Mean_Rating  Mean_Pop  \
# Genre
# Adventure            199978.67        179.19         5.88      6.00
# Animation             67432.97        176.99         6.45      4.75
# Fantasy              103920.15        166.01         5.93      5.36
# Family               107076.78        159.10         5.93      4.77
# Science Fiction       97847.96        131.52         5.48      5.00
# Action               201388.05        116.07         5.75      4.78
# Thriller             129724.55         69.52         5.74      4.51
# War                   15910.46         65.48         6.29      3.35
# Comedy               166845.05         64.10         5.97      3.25
# Mystery               34754.61         63.19         5.96      3.97
#
#                  Total_Movies
# Genre
# Adventure                3468
# Animation                1911
# Fantasy                  2290
# Family                   2740
# Science Fiction          3013
# ...

# %%
agg_gen.nlargest(10, "Mean_Rating")
# Out:
#              Total_Revenue  Mean_Revenue  Mean_Rating  Mean_Pop  Total_Movies
# Genre
# Documentary        1449.11          6.65         6.66      0.96          3868
# Animation         67432.97        176.99         6.45      4.75          1911
# History           14902.20         50.52         6.41      3.48          1391
# Music             13370.29         50.08         6.33      2.56          1587
# War               15910.46         65.48         6.29      3.35          1317
# Drama            160754.36         43.83         6.17      3.03         20056
# Crime             63375.73         58.52         6.10      4.15          4283
# Romance           73473.19         51.27         6.04      3.14          6662
# nan                 186.56          8.11         5.98      0.33          2162
# Foreign             291.54          3.51         5.97      0.77          1586

# %%
agg_gen.nlargest(10, "Mean_Pop")
# Out:
#                  Total_Revenue  Mean_Revenue  Mean_Rating  Mean_Pop  \
# Genre
# Adventure            199978.67        179.19         5.88      6.00
# Fantasy              103920.15        166.01         5.93      5.36
# Science Fiction       97847.96        131.52         5.48      5.00
# Action               201388.05        116.07         5.75      4.78
# Family               107076.78        159.10         5.93      4.77
# Animation             67432.97        176.99         6.45      4.75
# Thriller             129724.55         69.52         5.74      4.51
# Crime                 63375.73         58.52         6.10      4.15
# Mystery               34754.61         63.19         5.96      3.97
# Horror                30837.09         41.96         5.31      3.58
#
#                  Total_Movies
# Genre
# Adventure                3468
# Fantasy                  2290
# Science Fiction          3013
# Action                   6542
# Family                   2740
# ...

# %%
agg_gen_80 = gen[gen.release_date.between("1980-01-01", "1989-12-31")].groupby("Genre").agg(Total_Revenue=("revenue_musd", "sum"),
                            Mean_Revenue = ("revenue_musd", "mean"),
                            Mean_Rating = ("vote_average", "mean"),
                            Mean_Pop = ("popularity", "mean"),
                            Total_Movies = ("Genre", "count"))
agg_gen_80
# Out:
#                  Total_Revenue  Mean_Revenue  Mean_Rating  Mean_Pop  \
# Genre
# Action                11190.20         49.96         5.73      3.80
# Adventure             10678.15         70.72         5.84      4.70
# Animation              1033.85         35.65         6.50      2.53
# Comedy                13517.07         39.29         5.91      3.37
# Crime                  4464.45         33.32         6.07      4.23
# Documentary              19.07          2.12         6.69      0.59
# Drama                 10178.39         27.96         6.15      3.06
# Family                 4428.11         54.00         6.15      3.78
# Fantasy                4411.73         46.44         5.99      3.98
# Foreign                   8.83          2.21         5.99      0.71
# History                 715.13         23.84         6.34      3.32
# Horror                 2935.56         19.44         5.58      3.38
# Music                  1154.25         29.60         6.14      2.67
# ...

# %%
agg_gen_90 = gen[gen.release_date.between("1990-01-01", "1999-12-31")].groupby("Genre").agg(Total_Revenue=("revenue_musd", "sum"),
                            Mean_Revenue = ("revenue_musd", "mean"),
                            Mean_Rating = ("vote_average", "mean"),
                            Mean_Pop = ("popularity", "mean"),
                            Total_Movies = ("Genre", "count"))
agg_gen_90
# Out:
#                  Total_Revenue  Mean_Revenue  Mean_Rating  Mean_Pop  \
# Genre
# Action                26987.19         83.81         5.69      4.60
# Adventure             22289.78        121.80         5.75      5.51
# Animation              6555.72        136.58         6.42      4.10
# Comedy                29158.91         54.30         5.89      3.82
# Crime                 15080.36         64.45         6.13      5.25
# Documentary             193.25          8.78         6.73      0.83
# Drama                 35110.60         51.86         6.17      3.51
# Family                13416.66         95.15         5.63      4.68
# Fantasy               11080.89         88.65         5.81      5.23
# Foreign                  55.95          3.50         6.12      0.77
# History                2426.59         80.89         6.41      4.03
# Horror                 4584.56         38.53         5.28      3.91
# Music                  2121.93         58.94         6.37      3.60
# ...

# %%
fig, ax  = plt.subplots(figsize=(14,10))
agg_gen_80.Mean_Revenue.nlargest(10).plot(kind='bar', fontsize=15, rot=45, alpha=0.5, color="green")
agg_gen_90.Mean_Revenue.nlargest(10).plot(kind='bar', fontsize=15, rot=45, alpha=0.5)
plt.title("Mean Revenue (by genre and decade)", fontsize=20)
plt.legend(["1980s", "1990s"])
plt.ylabel("Revenue (in MUSD)", fontsize=15)
plt.show()

# %%
fig, ax  = plt.subplots(figsize=(14,10))
agg_gen_80.Mean_Rating.nlargest(10).plot(kind='bar', fontsize=15, rot=45, alpha=0.5, color="green")
agg_gen_90.Mean_Rating.nlargest(10).plot(kind='bar', fontsize=15, rot=45, alpha=0.5)
plt.title("Mean Rating (by genre and decade)", fontsize=20)
plt.legend(["1980s", "1990s"])
plt.ylabel("Rating)", fontsize=15)
plt.show()

# %%
fig, ax  = plt.subplots(figsize=(14,10))
agg_gen_80.Mean_Pop.nlargest(10).plot(kind='bar', fontsize=15, rot=45, alpha=0.5, color="green")
agg_gen_90.Mean_Pop.nlargest(10).plot(kind='bar', fontsize=15, rot=45, alpha=0.5)
plt.title("Mean Popularity (by genre and decade)", fontsize=20)
plt.legend(["1980s", "1990s"])
plt.ylabel("Popularuty)", fontsize=15)
plt.show()

# %% [markdown]
# ## Highest-rated Action movies of the 90ths

# %%
action_90 = gen[(gen.release_date.between("1990-01-01", "1999-12-31")) & (gen.Genre == "Action")]
action_90.nlargest(10, "vote_average")
# Out:
#          Genre                              title  revenue_musd  vote_average  \
# id
# 72886   Action  Mortal Kombat: The Journey Begins           NaN         10.00
# 87506   Action                                Pan           NaN         10.00
# 124853  Action                          Ten Benny           NaN         10.00
# 69848   Action                     One Man's Hero           NaN          9.30
# 55505   Action                     To Be the Best           NaN          9.00
# 18575   Action                               Pigs           NaN          8.40
# 31132   Action                              Kiler           NaN          8.10
# 38872   Action                     Kiler-ów 2-óch           NaN          8.10
# 24769   Action              Psy II: Ostatnia krew           NaN          8.00
# 31334   Action                           47 Ronin           NaN          8.00
#
#         popularity release_date  vote_count
# id
# 72886         0.71   1995-08-28        1.00
# ...

# %%
action_90.drop("Genre", axis=1, inplace=True)
action_90.set_index("title", inplace=True, drop=True)
action_90
# Out:
# /var/folders/tb/_zm480yx3x55hmpk68x5ldb00000gp/T/ipykernel_98648/3845771239.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   action_90.drop("Genre", axis=1, inplace=True)
#                      revenue_musd  vote_average  popularity release_date  \
# title
# Judgment Night              12.14          6.40        5.54   1993-10-15
# The Fifth Element          263.92          7.30       24.31   1997-05-07
# Armageddon                 553.80          6.50       13.24   1998-07-01
# Run Lola Run                 7.27          7.20        7.77   1998-08-20
# Predator 2                  57.12          6.00       11.74   1990-11-20
# ...                           ...           ...         ...          ...
# Provocateur                   NaN           NaN        0.00   1995-05-31
# ...

# %%
action_90.nlargest(20, "vote_count")
# Out:
#                                            revenue_musd  vote_average  \
# title
# The Matrix                                       463.52          7.90
# Star Wars: Episode I - The Phantom Menace        924.32          6.40
# Men in Black                                     589.39          6.90
# Terminator 2: Judgment Day                       520.00          7.70
# The Fifth Element                                263.92          7.30
# Braveheart                                       210.00          7.70
# Independence Day                                 816.97          6.70
# The Mummy                                        415.89          6.60
# Mission: Impossible                              457.70          6.70
# Armageddon                                       553.80          6.50
# The Lost World: Jurassic Park                    229.07          6.20
# Die Hard: With a Vengeance                       366.10          6.90
# ...

# %%
action_90[action_90.vote_count >= 1000].nlargest(10, "vote_average")
# Out:
#                             revenue_musd  vote_average  popularity  \
# title
# The Matrix                        463.52          7.90       33.37
# Braveheart                        210.00          7.70       20.76
# Terminator 2: Judgment Day        520.00          7.70       22.66
# Heat                              187.44          7.70       17.92
# The Fifth Element                 263.92          7.30       24.31
# The Fugitive                      368.88          7.20       10.09
# Total Recall                      261.32          7.10       12.95
# Men in Black                      589.39          6.90       15.78
# From Dusk Till Dawn                25.84          6.90       15.34
# Die Hard: With a Vengeance        366.10          6.90       15.14
#
#                            release_date  vote_count
# title
# The Matrix                   1999-03-30     9079.00
# Braveheart                   1995-05-24     3404.00
# Terminator 2: Judgment Day   1991-07-01     4274.00
# ...

# %%
action_90[action_90.vote_count >= 1000].nlargest(10, "popularity")
# Out:
#                             revenue_musd  vote_average  popularity  \
# title
# The Matrix                        463.52          7.90       33.37
# The Fifth Element                 263.92          7.30       24.31
# The Mummy                         415.89          6.60       23.98
# Terminator 2: Judgment Day        520.00          7.70       22.66
# Braveheart                        210.00          7.70       20.76
# Die Hard 2                        240.03          6.60       18.79
# Heat                              187.44          7.70       17.92
# Independence Day                  816.97          6.70       17.63
# Alien³                            159.77          6.20       17.13
# Batman & Robin                    238.21          4.20       17.04
#
#                            release_date  vote_count
# title
# The Matrix                   1999-03-30     9079.00
# The Fifth Element            1997-05-07     3962.00
# The Mummy                    1999-04-16     2796.00
# ...

# %%
plt.figure(figsize = (12,8))
action_90[action_90.vote_count >= 1000].vote_average.nlargest(10).plot(kind='bar', fontsize=15, rot=45)
plt.title("Highest-Rated Action Movies of the 90s", fontsize=20)
plt.ylabel("Rating", fontsize=15)
plt.show()
